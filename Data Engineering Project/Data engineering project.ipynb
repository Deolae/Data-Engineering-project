# %% [markdown]
# ## The purpose of this project is to extract data from multiple sources, transform it, and then load it into a data storage solution. The targeted subject is "A.I News".

# %% [markdown]
# ## 1 - Data ingestion:

# %% [markdown]
# ## ● csv extraction:

# %% [markdown]
# ### The csv file used contains relevant and irrelevant data to A.I, we're going to extract the relevant data

# %% [markdown]
# #### Reading csv file:

# %%
import pandas as pd
import numpy as np
import re

#Reading the csv file
csv_file = pd.read_csv(r"C:/Users/osama/Desktop/Third year - Second semester/Data Engineering/Project/Project Files/articulos_ml.csv")
csv_file = pd.DataFrame(csv_file)
csv_file
# Out:
#                                                  Title  \
# 0    What is Machine Learning and how do we use it ...
# 1     10 Companies Using Machine Learning in Cool Ways
# 2    How Artificial Intelligence Is Revolutionizing...
# 3    Dbrain and the Blockchain of Artificial Intell...
# 4    Nasa finds entire solar system filled with eig...
# ..                                                 ...
# 156  [Log] 83: How Google Uses Machine Learning And...
# 157  [Log] 84: Zuck Knows If You've Been Bad Or Goo...
# 158  [Log] 85: Microsoft Improves Windows Phone Voi...
# 159  [Log] 86: How Google's Acquisition Of DNNresea...
# 160   [Log] 87: Google's Cloud Is Eating Apple's Lunch
#
#                                                    url  Word count  \
# 0    https://blog.signals.network/what-is-machine-l...        1888
# 1                                                  NaN        1742
# 2                                                  NaN         962
# 3                                                  NaN        1221
# 4                                                  NaN        2039
# ..                                                 ...         ...
# 156  [Log] 83: http://feedproxy.google.com/~r/Techc...        3239
# 157  [Log] 84: http://feedproxy.google.com/~r/Techc...        2566
# 158  [Log] 85: http://feedproxy.google.com/~r/Techc...        2089
# 159  [Log] 86: http://feedproxy.google.com/~r/Techc...        1530
# 160  [Log] 87: http://feedproxy.google.com/~r/Techc...         953
#
#      # of Links  # of comments  # Images video  Elapsed days  # Shares
# 0             1            2.0               2            34    200000
# 1             9            NaN               9             5     25000
# 2             6            0.0               1            10     42000
# 3             3            NaN               2            68    200000
# 4             1          104.0               4           131    200000
# ..          ...            ...             ...           ...       ...
# 156           3           11.0               1            84      3239
# 157           3            8.0               4            85     25019
# 158           4            4.0               1            86     49614
# 159           4           12.0               3            87     33660
# 160           6           13.0               2            88      5956
#
# [161 rows x 8 columns]

# %%
#Getting column names from csv file for the new csv dataframe
csv_columns = csv_file.columns

#Making new dataframe
csv_df = pd.DataFrame(columns = csv_columns)
csv_df
# Out:
# Empty DataFrame
# Columns: [Title, url, Word count, # of Links, # of comments, # Images video, Elapsed days, # Shares]
# Index: []

# %% [markdown]
# #### Cleaning and transforming data:

# %%
#If a title contains these words it is chosen for the new dataframe
matches = ["Artificial Intelligence", "AI", "A.I", "A.I."]

#This regular expression pattern to match "[Log]" followed by one or two numbers and remove it
#Note: (the csv file data titles all started with "[Log] ##:", for example, "[Log] 23:", so this pattern is for removing it)
pattern = r"\[Log\]\s*\d{1,2}:"

#Loop to check if the titles contain the matches and adds them to the new dataframe 
for index, row in csv_file.iterrows():                 #Iterate for each row 
    if any(x in row["Title"] for x in matches):        #search each row's title column for matches
        title = re.sub(pattern, "", str(row["Title"])) # Remove "[log]" along with subsequent numbers
        row["Title"] = title                           # Update the title in the row
        
        url = re.sub(pattern, "", str(row["url"]))  # Remove "[log]" along with subsequent numbers
        row["url"] = url                            # Update the url in the row
        
        csv_df = csv_df.append(row)
        
#Note: (when we turned the attributes "title" and "url" into strings, the "NaN" values turned into "nan")
#Converting all "nan" into actual missing values then dropping all missing values 
csv_df = csv_df.replace('nan', np.nan)
csv_df = csv_df.dropna()

# "# of comments" column was float64, I changed it to int to match the other numerical columns
csv_df['# of comments'] = csv_df['# of comments'].astype(int)

csv_df
# Out:
#                                                  Title  \
# 17   Who’s a good AI? Dog-based data creates a cani...
# 44   Top 20 PythonAI and MachineLearning Open Sourc...
# 73    Allegro.AI nabs $11M for ‘deep learning as a ...
# 75            UK report urges action to combat AI bias
# 78    Arm chips with Nvidia AI could change the Int...
# 87           Frank Chen will make you a believer in AI
# 99    Frank Lessons on AI from the Developer of the...
# 101   Prisma shifts focus to b2b with an API for AI...
# 104                      What you should know about AI
# 105   HBO’s Silicon Valley on A.I. driven products:...
# 111   MIT CSAIL research offers a fully automated w...
# 113   Someone scraped 40,000 Tinder selfies to make...
# 117   Google’s smarter, A.I.-powered translation sy...
# 118   Mark Zuckerberg’s ‘Jarvis’ Addresses AI’s Big...
# 122   Mark Cuban on Why You Need to Study Artificia...
# 124   Mark Zuckerberg’s ‘Jarvis’ Addresses AI’s Big...
# 126   Google’s AI Experiments help you understand n...
# 134   Facebook’s Artificial Intelligence Research l...
# 149   NVIDIA announces a supercomputer aimed at dee...
# 150   Following Artificial Intelligence Breakthroug...
# 152   Facebook Updates Progress on Artificial Intel...
# 154   Understanding Artificial Intelligence &#8211;...
#
#                                                    url  Word count  \
# 17   https://techcrunch.com/2018/04/11/whos-a-good-...         635
# 44   https://www.kdnuggets.com/2018/02/top-20-pytho...        1184
# 73    https://techcrunch.com/2018/04/25/allegro-ai-...        1864
# 75    https://techcrunch.com/2018/04/16/uk-report-u...        1741
# 78    https://techcrunch.com/2018/03/27/arm-chips-w...        1864
# 87    https://mixpanel.com/blog/2017/12/12/frank-ch...        1913
# 99    https://mxpnlcms.wpengine.com/blog/2017/08/31...        1007
# 101   https://techcrunch.com/2017/08/19/prisma-shif...        3019
# 104   https://techcrunch.com/2017/08/01/what-you-sh...        2224
# 105   https://mxpnlcms.wpengine.com/blog/2017/07/27...        1778
# 111   https://techcrunch.com/2017/06/30/mit-csail-r...        1612
# 113   https://techcrunch.com/2017/04/28/someone-scr...        2721
# 117   https://techcrunch.com/2017/03/06/googles-sma...        2877
# 118   https://www.cygnismedia.com/blog/artificial-i...         776
# 122   https://bothsidesofthetable.com/mark-cuban-on...        2904
# 124   http://www.cygnismedia.com/blog/artificial-in...        2894
# 126   http://feedproxy.google.com/~r/Techcrunch/~3/...        3225
# 134   http://feedproxy.google.com/~r/Techcrunch/~3/...        2282
# 149   http://feedproxy.google.com/~r/Techcrunch/~3/...        1871
# 150   http://feedproxy.google.com/~r/Techcrunch/~3/...        2513
# 152   http://www.adweek.com/socialtimes/artificial-...         912
# 154   http://rss.feedsportal.com/c/35261/f/656072/s...        1542
#
#      # of Links  # of comments  # Images video  Elapsed days  # Shares
# 17            3              1               2            12      3200
# 44           39              8               1            63      1300
# 73            6             12               2             1     42406
# 75            5             10               3             3     35691
# 78            1             10               4             6     30756
# 87            5              1               6            15      5261
# 99            2              7               6            27     10574
# 101           5              3               2            29     13586
# 104           8              2               3            32     32248
# 105           4             11               6            33      8001
# 111           5              5               2            39     39091
# 113           3             14               6            41     25850
# 117           4              2               6            45     19420
# 118           1              7               6            46      3298
# 122           7             14               1            50      7260
# 124           5              6               3            52     23152
# 126           1              4               3            54     34669
# 134           1              1               3            62     54198
# 149           6             14               4            77     26194
# 150           7              3               4            78     55914
# 152           5             14               6            80      1824
# 154           6              1               6            82     22359

# %% [markdown]
# ## ● web scraping extraction:

# %%
from bs4 import BeautifulSoup 
import requests

#AI news dataframe
AiNews = pd.DataFrame(columns = ['Title','Description','Date','Genre', 'url'])
AiNews
# Out:
# Empty DataFrame
# Columns: [Title, Description, Date, Genre, url]
# Index: []

# %%
#Temporary containers for the attributes, once all data is collected they're added into the AiNews dataframe
AiNews_Title = []
AiNews_Description = []
AiNews_Date = []
AiNews_Genre = []
AiNews_url = []

# %% [markdown]
# #### Extraction functions:

# %%
#Creating a BeautifulSoup object to use in extraction
url = "https://www.artificialintelligence-news.com/"  #Website link
response = requests.get(url)                          #Get website
soup = BeautifulSoup(response.content, 'html.parser') #read website html content

def AiNews_Title_extraction():
    titles = soup.select('header.article-header') #Title data tag
    for x in titles:                              #Get all news titles
        text = x.get_text().strip()               #Returns the text as a string, without any tags or markup
        AiNews_Title.append(text)
        
        
def AiNews_Description_extraction():
    descriptions = soup.select('div.cell.small-12.medium-8.large-6') #Description data tag
    for x in descriptions:                                           #Get all news descriptions
        text = x.get_text().strip()                                  #Returns the text as a string, without any tags or markup
        AiNews_Description.append(text)
        
        
def AiNews_Date_and_AiNews_Genre_extraction(): 
    extracted = soup.select('div.byline')                        #Tag which contained both 'Date' and 'Genre' data
    for x in extracted:
        text = x.get_text().strip()                              #Returns the text as a string, without any tags or markup
        text = text.split('                    |\n            ') #Split based on the seperator between 'Date' and 'Genre'
        dates, genres = zip(*[text])                             #Storing 'Date' and 'Genre' data into different variables

        #Filter out the genre and date
        AiNews_Genre.extend(genres)
        AiNews_Date.extend(dates)

        #Some dates and genres were lists insides of the list extracted, this converts them all to strings
        filtered_genre_output = [item for item in AiNews_Genre if isinstance(item, str)]
        filtered_date_output = [item for item in AiNews_Date if isinstance(item, str)]
        
        
def AiNews_url_extraction():
    links = soup.select('header.article-header') #the header contains the link
    for x in links:
        link = x.find('a')                       #reaching the <a> tag to extract the link
        link = link['href']                      #extracting the url
        AiNews_url.append(link)

# %% [markdown]
# #### Refresh function:

# %%
def AiNews_Refresh():
    global AiNews
    #Append all extracted data to temporary containers
    AiNews_Title_extraction()
    AiNews_Description_extraction()
    AiNews_Date_and_AiNews_Genre_extraction()
    AiNews_url_extraction()

    #Convert temporary containers list into series as string
    title_series = pd.Series(AiNews_Title, dtype='str')
    description_series = pd.Series(AiNews_Description, dtype='str')
    date_series = pd.Series(AiNews_Date, dtype='str')
    genre_series = pd.Series(AiNews_Genre, dtype='str')
    url_series = pd.Series(AiNews_url, dtype='str')

    #Concatenate the series in a dictionaty to turn into a dataframe
    new_data = {                              #Adding the data to a dictionary to avoid array out of index error
        'Title': title_series,
        'Description': description_series,
        'Date': date_series,
        'Genre': genre_series,
        'url': url_series
    }
    
    new_df = pd.DataFrame(new_data)          #Making a dataframe with the dictionary
    AiNews = pd.concat([AiNews, new_df], ignore_index=True)   #Concatenate the new_df dataframe with AiNews

    #Dropping duplicates and NaN
    AiNews.drop_duplicates(subset=['Title'], inplace=True)
    AiNews = AiNews.dropna()
    display(AiNews)

# %% [markdown]
# #### Refresh data every 2 hours to get latest news:

# %%
import time
import threading

#Define the interval in seconds (120 minutes = 120 * 60 seconds)
interval = 120 * 60

#Define a function to run AiNews_Add at the specified interval
def run_AiNews_Refresh():
    while True:
        #Call the AiNews_Refresh function
        AiNews_Refresh()
        
        #Wait for the specified interval
        time.sleep(interval)

#Start a background thread to run the function
thread = threading.Thread(target=run_AiNews_Refresh)
thread.daemon = True
thread.start()
# Out:
#                                                 Title  \
# 0   Steve Frederickson, Lucy.ai: How AI powers a n...
# 1   Meta’s open-source speech AI models support ov...
# 2   Beijing launches campaign against AI-generated...
# 3     SAP taps Microsoft’s generative AI technologies
# 4            OpenAI CEO: AI regulation ‘is essential’
# 5   Jay Migliaccio, IBM Watson: On leveraging AI t...
# 6   Iurii Milovanov, SoftServe: How AI/ML is helpi...
# 7   AI and Big Data Expo North America begins in l...
# 8                EU committees green-light the AI Act
# 9          Wozniak warns AI will power next-gen scams
# 10  Infocepts CEO Shashank Garg on the D&A market ...
# 11   AI ‘godfather’ warns of dangers and quits Google
# 12  Palantir demos how AI can be used in the military
# 13  FTC Chairwoman: There is no ‘AI exemption’ to ...
# 14  Bill Gates: AI will be teaching kids literacy ...
# 15  Google creates new AI division to challenge Op...
# 16           Demand for AI expertise surges by 1,000%
# 17  Google will test a more AI-enhanced search nex...
# 18             OpenAI is not currently training GPT-5
# 19  Arvind Jain, Glean: On using AI to surface kno...
# 20  ​​Italy will lift ChatGPT ban if OpenAI fixes ...
# 21      Alibaba unveils ChatGPT rival and custom LLMs
# 22  How AI can transform the way enterprises test ...
# 23  Biden: AI can help with difficult challenges, ...
# 24    The risk and reward of ChatGPT in cybersecurity
# 25  AI think tank calls GPT-4 a risk to public safety
# 26  UK details ‘pro-innovation’ approach to AI reg...
# 27  Clearview AI used by US police for almost 1M s...
# 28  What will AI regulation look like for businesses?
# 29      Mozilla.ai picks up OpenAI’s founding mission
#
#                                           Description           Date  \
# 0   In an interview at AI & Big Data Expo with Ste...    9 June 2023
# 1   Advancements in machine learning and speech re...    8 June 2023
# 2   China's Cyberspace Administration (CAC) has la...    6 June 2023
# 3   SAP and Microsoft have announced a new collabo...    31 May 2023
# 4   OpenAI CEO Sam Altman testified in front of a ...    25 May 2023
# 5   IBM has been refining its AI solutions for dec...    23 May 2023
# 6   Could you tell us a little bit about SoftServe...    18 May 2023
# 7   The AI and Big Data Expo North is taking place...    17 May 2023
# 8   The Internal Market Committee and the Civil Li...    16 May 2023
# 9   Apple co-founder Steve Wozniak has raised conc...    15 May 2023
# 10  Could you tell us a little bit your company, I...    15 May 2023
# 11  Geoffrey Hinton, known as the "Godfather of AI...    11 May 2023
# 12  Palantir has demonstrated how AI can be used f...    11 May 2023
# 13  FTC Chairwoman Lina Khan has warned that the U...     9 May 2023
# 14  AI chatbots could be used to improve children’...     9 May 2023
# 15  Google has consolidated its AI research labs, ...     2 May 2023
# 16  Fiverr has released its seventh Business Trend...  28 April 2023
# 17  Google is set to publicly test a more deeply A...  26 April 2023
# 18  Experts calling for a pause on AI development ...  24 April 2023
# 19  Rapid advancements in AI are heralding a new g...  21 April 2023
# 20  Italy’s data protection authority has said tha...  18 April 2023
# 21  Chinese tech giant Alibaba has unveiled a Chat...  17 April 2023
# 22  The digital world is evolving rapidly, and bus...  17 April 2023
# 23  President Biden believes that AI can help solv...  14 April 2023
# 24  Unless you’ve been on a retreat in some far-fl...  13 April 2023
# 25  An AI think tank has filed a complaint with th...  11 April 2023
# 26  The UK government has unveiled a new regulator...   6 April 2023
# 27  Facial recognition firm Clearview AI has revea...   5 April 2023
# 28  Unlike food, medicine, and cars, we have yet t...   3 April 2023
# 29  Mozilla's new startup will build "trustworthy"...  31 March 2023
#
#                       Genre                                                url
# 0              Applications  https://www.artificialintelligence-news.com/20...
# 1   Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 2              Applications  https://www.artificialintelligence-news.com/20...
# 3              Applications  https://www.artificialintelligence-news.com/20...
# 4              Applications  https://www.artificialintelligence-news.com/20...
# 5              Applications  https://www.artificialintelligence-news.com/20...
# 6              Applications  https://www.artificialintelligence-news.com/20...
# 7              Applications  https://www.artificialintelligence-news.com/20...
# 8   Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 9              Applications  https://www.artificialintelligence-news.com/20...
# 10             Applications  https://www.artificialintelligence-news.com/20...
# 11  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 12  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 13  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 14  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 15  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 16             Applications  https://www.artificialintelligence-news.com/20...
# 17             Applications  https://www.artificialintelligence-news.com/20...
# 18             Applications  https://www.artificialintelligence-news.com/20...
# 19  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 20  Artificial Intelligence  https://www.artificialintelligence-news.com/20...
# 21             Applications  https://www.artificialintelligence-news.com/20...
# 22             Applications  https://www.artificialintelligence-news.com/20...
# 23             Applications  https://www.artificialintelligence-news.com/20...
# 24             Applications  https://www.artificialintelligence-news.com/20...
# 25             Applications  https://www.artificialintelligence-news.com/20...
# 26             Applications  https://www.artificialintelligence-news.com/20...
# 27             Applications  https://www.artificialintelligence-news.com/20...
# 28             Applications  https://www.artificialintelligence-news.com/20...
# 29             Applications  https://www.artificialintelligence-news.com/20...

# %% [markdown]
# ## ● PDF Extraction:

# %%
import PyPDF2

#Function to search for certain keywords inside the pdf file
def search_pdf_for_word(pdf_path, keywords):
    matching_paragraphs = [] #list to store the matching paragraphs
    
    with open(pdf_path, 'rb') as file:          #Open the pdf file
        pdf_reader = PyPDF2.PdfReader(file)     #Read the pdf file
        total_pages = len(pdf_reader.pages)     #Get number of pages
        
        #Loop to reach each page and extract text from it
        for page_num in range(2, total_pages):  #starting from page 2 to avoid searching in index and introduction   
            
            page = pdf_reader.pages[page_num]   #read all pages
            text = page.extract_text()          #extract text from pages
            #text = text.replace('\n', '')      # Remove "\n" characters from the text
            
            #Split text into paragraphs based on newline characters
            paragraphs = text.split('\n')       
            
            #Search for paragraphs containing the keywords (case-insensetive)
            for paragraph in paragraphs:
                if all(keyword.lower() in paragraph.lower() for keyword in keywords):#check if all words match in the paragraph
                    matching_paragraphs.append(paragraph)                            #append matching paragraph
                    
    return matching_paragraphs

# %% [markdown]
# #### The pdf file is about AI, but we want to search for AI news specifically, so the keywords will be "news" and "ai"

# %%
pdf_path = "C:/Users/osama/Desktop/Third year - Second semester/Data Engineering/Project/Project Files/AI in the News.pdf"
keywords = ['news', 'ai']

pdf_result = search_pdf_for_word(pdf_path, keywords)
pdf_result = pd.DataFrame(pdf_result, columns=["Matching results"]) #saving results in a datraframe
pdf_result
# Out:
#                                      Matching results
# 0   adoption and use of AI and re-examines questio...
# 1   the US and Europe, I argue that the introducti...
# 2   mainly flown from their control over the chann...
# 3   connection in the news . With the complexity a...
# 4   lock-in effects, news organisations will likel...
# ..                                                ...
# 61  the latter into their orbit. Platform companie...
# 62  a development. Despite its flaws, AI potential...
# 63  Domingo, David. 2008. “Interactivity in the Da...
# 64  Xu, Craig. 2021. ‘Australia: The News Media Ba...
# 65  3 October 2021. https://inforrm.org/2021/10/03...
#
# [66 rows x 1 columns]

# %% [markdown]
# ## 2 - Data Storage:

# %% [markdown]
# #### Storing data in MongoDB:

# %%
from pymongo import MongoClient

#Convert the dataframes to dictionaries/records because MongoDB uses .JSON files
csv_dict = csv_df.to_dict(orient='records')
AiNews_dict = AiNews.to_dict(orient='records')
pdf_result_dict = pdf_result.to_dict(orient='records')

#Define the sections and the corresponding data which will be saved in it
#sections_data = {
#    'CSV Extraction Data': csv_dict,
#    'Web Scraping Data': AiNews_dict,
#    'PDF Extraction Data': pdf_result_dict
#}

# %%
#Connect to your MongoDB database:
client = MongoClient('mongodb+srv://Deolae:Zaqw1234@cluster0.5a73pqg.mongodb.net/')
db = client['Data_Storage']

#Define a collection where you want to store your data:
csv_collection = db['CSV data']
WebScraping_collection = db['WebScraping data']
pdf_collection = db['PDF data']

#Insert the data into separate collections:
csv_collection.insert_many(csv_dict)
WebScraping_collection.insert_many(AiNews_dict)
pdf_collection.insert_many(pdf_result_dict)

#Close the MongoDB connection
client.close()
